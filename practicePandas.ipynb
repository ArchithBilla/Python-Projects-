# %% [markdown]
# <a href="https://colab.research.google.com/github/ArchithBilla/Python-Projects-/blob/main/practicePandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("world_population.csv")

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.300000e+02     2.330000e+02     2.300000e+02
# mean   117.500000     3.463225e+07     3.360071e+07     3.206600e+07
# std     67.694165     1.378892e+08     1.358732e+08     1.315071e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.064710e+05     3.942950e+05
# 50%    117.500000     5.762857e+06     5.456681e+06     5.244415e+06
# 75%    175.750000     2.265372e+07     2.152263e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.270000e+02     2.270000e+02     2.290000e+02     2.290000e+02
# mean      3.027016e+07     2.684050e+07     1.933046e+07     1.628288e+07
# std       1.260742e+08     1.133525e+08     8.130962e+07     6.934547e+07
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
numeric_cols = [
    "2022 Population","2020 Population","2015 Population","2010 Population",
    "2000 Population","1990 Population","1980 Population","1970 Population",
    "Area (km²)","Density (per km²)","Growth Rate","World Population Percentage"
]

df_clean = df.copy()
for col in numeric_cols:
    df_clean[col] = df_clean[col].fillna(df_clean[col].median())

# %%
df_clean.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df_clean.to_csv("world_population_clean.csv", index=False)

# %%
corr = df_clean.corr(numeric_only = True)
corr
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Rank                         1.000000        -0.357956        -0.355784
# 2022 Population             -0.357956         1.000000         0.999936
# 2020 Population             -0.355784         0.999936         1.000000
# 2015 Population             -0.350095         0.999382         0.999665
# 2010 Population             -0.343795         0.998226         0.998710
# 2000 Population             -0.339023         0.994463         0.995432
# 1990 Population             -0.329509         0.732807         0.737491
# 1980 Population             -0.325161         0.729553         0.734431
# 1970 Population             -0.332305         0.972682         0.974762
# Area (km²)                  -0.381505         0.453355         0.455058
# Density (per km²)            0.129070        -0.027533        -0.027158
# Growth Rate                 -0.219345        -0.021365        -0.025468
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()
